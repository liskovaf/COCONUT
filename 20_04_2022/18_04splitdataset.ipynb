# %% [markdown]
# #### Splitting dataset

# %%
from rdkit.Chem import AllChem as Chem
from rdkit.Chem import Descriptors
from rdkit.Chem.Draw import IPythonConsole
import pandas as pd
from rdkit.Chem import rdMolDescriptors as rdescriptors
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys    
import pubchempy as pcp
import warnings
warnings.filterwarnings('ignore')
from rdkit import RDLogger 
RDLogger.DisableLog('rdApp.*')
from sklearn.utils import shuffle

# %%
#Loading zinc database from csv 
suppl_csv = pd.read_csv('../data/ZINCECFP.csv', delimiter = ' ')
suppl_csv
# Out:
#           Zinc_id                                             Smiles  \
# 0         1589384                            N=C(N)NCC[C@H](N)C(=O)O
# 1        83822513                                CN(C)CC(=O)NCC(=O)O
# 2       214763687                              O=C(O)CN1CCCNS1(=O)=O
# 3       306392345         O=C(O)[C@@H]1C[C@H]2O[C@H]1[C@H](O)[C@H]2O
# 4        85343607                      N[C@@H]1N=C2N=C(O)N=C2C(=O)N1
# ...           ...                                                ...
# 379007   97986502  Cc1ccc(C(=O)N(c2ccc(N(C(=O)c3ccc(C)cc3)S(=O)(=...
# 379008   97948800  CCc1c(-c2ccc(OC)c(OC)c2)nn(-c2nc(-c3ccc(C)cc3)...
# 379009   54274624  Cc1cc(N2CCN(CCOc3cccc4ccccc34)CC2)n2nc(C)c(-c3...
# 379010    2093448        CCOc1cc(CNc2cc(Cl)ccc2C)cc(I)c1OCc1ccccc1Cl
# 379011   24193211  CCCOc1cccc([C@@H]2C(S(=O)(=O)c3ccccc3)=C(O)C(=...
#
#                 MW     logP                        Inchi         Inchi_s  \
# 0       160.096026 -1.72853  IFPQOXNWLSRZKX-VKHMYHEASA-N  IFPQOXNWLSRZKX
# 1       160.084792 -1.25120  HQFNONZTUQSPJS-UHFFFAOYSA-N  HQFNONZTUQSPJS
# 2       194.036128 -1.38890  KCIDTUHJDPZBTQ-UHFFFAOYSA-N  KCIDTUHJDPZBTQ
# 3       174.052823 -1.41990  ZZTJOHOETCDWML-VFUOTHLCSA-N  ZZTJOHOETCDWML
# 4       167.044324 -1.87440  OSXQHYVRCFCLQV-SCSAIBSYSA-N  OSXQHYVRCFCLQV
# ...            ...      ...                          ...             ...
# 379007  636.051720  6.49784  KYPDAVIHIYTGQW-UHFFFAOYSA-N  KYPDAVIHIYTGQW
# 379008  604.229740  7.58732  AWQWFNRTEBAZJO-UHFFFAOYSA-N  AWQWFNRTEBAZJO
# 379009  511.213888  6.02074  HAHVCBFPDRUVIL-UHFFFAOYSA-N  HAHVCBFPDRUVIL
# 379010  541.007232  7.49622  IYFPBZIIJDRXMB-UHFFFAOYSA-N  IYFPBZIIJDRXMB
# 379011  517.051749  6.11360  LDSGAMYJONZMDX-JOCHJYFZSA-N  LDSGAMYJONZMDX
#
#         Name                                               ECFP  \
# 0       ZINC  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1       ZINC  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2       ZINC  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3       ZINC  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4       ZINC  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# ...      ...                                                ...
# 379007  ZINC  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 379008  ZINC  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 379009  ZINC  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 379010  ZINC  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 379011  ZINC  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                                    Bitset
# 0       [1, 80, 140, 197, 389, 623, 650, 667, 739, 786...
# 1       [41, 80, 197, 339, 389, 390, 650, 652, 807, 88...
# 2       [80, 187, 190, 207, 305, 307, 389, 469, 650, 8...
# 3       [209, 221, 285, 389, 650, 656, 807, 926, 1017,...
# 4       [15, 106, 301, 314, 378, 584, 650, 664, 724, 7...
# ...                                                   ...
# 379007  [14, 234, 235, 241, 350, 383, 517, 587, 650, 6...
# 379008  [80, 94, 114, 121, 140, 208, 235, 249, 289, 29...
# 379009  [13, 74, 80, 92, 140, 212, 216, 262, 296, 378,...
# 379010  [80, 99, 165, 216, 237, 255, 294, 295, 333, 36...
# 379011  [13, 76, 80, 233, 294, 314, 319, 322, 350, 366...
#
# [379012 rows x 9 columns]

# %%
suppl_csv = suppl_csv.sample(frac=1).reset_index(drop=True)

# %%
suppl_csv.head()
# Out:
#      Zinc_id                                             Smiles          MW  \
# 0    8613683              CC(=O)O[C@H](C)C(=O)NC(C)(C)CC(C)(C)C  243.183444
# 1   12321558  Cc1cc(C)nc(SCc2nc3cc(NC(=O)c4ccc(Cl)nc4Cl)ccc3...  472.063986
# 2   72168908           CCS(=O)(=O)N1CCN(c2nc(COC)nc3c2cnn3C)CC1  354.147410
# 3    2312843  CCc1ccc(NC2=Nc3ccccc3N3C2=Nc2c(c(C)nn2-c2ccccc...  542.198573
# 4  967566026  C=C[C@@](C)(CC)C(=O)N1CCC[C@H](N(C)C(=O)c2ccns...  349.182398
#
#       logP                        Inchi         Inchi_s  Name  \
# 0  2.26900  CFWQOMWFLLALKD-SECBINFHSA-N  CFWQOMWFLLALKD  ZINC
# 1  5.22654  FACCAYRGNNVIPH-UHFFFAOYSA-N  FACCAYRGNNVIPH  ZINC
# 2 -0.01860  IFIKBMFSNYMHTI-UHFFFAOYSA-N  IFIKBMFSNYMHTI  ZINC
# 3  8.19182  WZMMYEVYZXQWRF-PMERELPUSA-N  WZMMYEVYZXQWRF  ZINC
# 4  3.19850  OGEFYLXMRIOMGU-KSSFIOAISA-N  OGEFYLXMRIOMGU  ZINC
#
#                                                 ECFP  \
# 0  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                               Bitset
# 0  [1, 69, 80, 114, 283, 354, 383, 385, 392, 573,...
# 1  [45, 67, 80, 116, 184, 191, 217, 298, 318, 339...
# 2  [43, 80, 105, 115, 120, 130, 267, 268, 294, 35...
# 3  [80, 92, 95, 145, 175, 191, 216, 273, 294, 310...
# 4  [80, 114, 145, 211, 217, 294, 295, 369, 378, 3...

# %%
df_split = np.array_split(suppl_csv, 10)

# %%
df_split[0]
# Out:
#           Zinc_id                                             Smiles  \
# 0         8613683              CC(=O)O[C@H](C)C(=O)NC(C)(C)CC(C)(C)C
# 1        12321558  Cc1cc(C)nc(SCc2nc3cc(NC(=O)c4ccc(Cl)nc4Cl)ccc3...
# 2        72168908           CCS(=O)(=O)N1CCN(c2nc(COC)nc3c2cnn3C)CC1
# 3         2312843  CCc1ccc(NC2=Nc3ccccc3N3C2=Nc2c(c(C)nn2-c2ccccc...
# 4       967566026  C=C[C@@](C)(CC)C(=O)N1CCC[C@H](N(C)C(=O)c2ccns...
# ...           ...                                                ...
# 37897   113804313              CCCN1c2cc(C)c(C=O)cc2[C@@H](C)CC1(C)C
# 37898     4861000      CCCn1c(SCC(=O)Nc2ccc3c(c2)OCCO3)nnc1-c1cccnc1
# 37899  1772702375  Cc1nc2n(n1)CC(=O)NCCN(C(=O)c1ccc(N(C)S(C)(=O)=...
# 37900  2037879936  Cc1cc(CCC(=O)N[C@@H](CC(C)C)C(=O)N[C@@H](CC(C)...
# 37901   222913186  CCNC(=O)[C@@H](C)N(Cc1cccc(Cl)c1)C(=O)CN(c1ccc...
#
#                MW     logP                        Inchi         Inchi_s  Name  \
# 0      243.183444  2.26900  CFWQOMWFLLALKD-SECBINFHSA-N  CFWQOMWFLLALKD  ZINC
# 1      472.063986  5.22654  FACCAYRGNNVIPH-UHFFFAOYSA-N  FACCAYRGNNVIPH  ZINC
# 2      354.147410 -0.01860  IFIKBMFSNYMHTI-UHFFFAOYSA-N  IFIKBMFSNYMHTI  ZINC
# 3      542.198573  8.19182  WZMMYEVYZXQWRF-PMERELPUSA-N  WZMMYEVYZXQWRF  ZINC
# 4      349.182398  3.19850  OGEFYLXMRIOMGU-KSSFIOAISA-N  OGEFYLXMRIOMGU  ZINC
# ...           ...      ...                          ...             ...   ...
# 37897  259.193614  4.30972  JFXBAKNXAQWLGE-ZDUSSCGKSA-N  JFXBAKNXAQWLGE  ZINC
# 37898  411.136511  3.25210  HXBMYESGCCHKLW-UHFFFAOYSA-N  HXBMYESGCCHKLW  ZINC
# 37899  751.347566  1.08022  RPCYPIIVSJPAHQ-XXFUAGPLSA-N  RPCYPIIVSJPAHQ  ZINC
# 37900  475.315855  2.33102  YCYVMIXPMJOIPK-SFTDATJTSA-N  YCYVMIXPMJOIPK  ZINC
# 37901  577.120497  4.75070  VVHGNCRMULXDRB-LJQANCHMSA-N  VVHGNCRMULXDRB  ZINC
#
#                                                     ECFP  \
# 0      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# ...                                                  ...
# 37897  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 37898  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 37899  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 37900  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 37901  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                                   Bitset
# 0      [1, 69, 80, 114, 283, 354, 383, 385, 392, 573,...
# 1      [45, 67, 80, 116, 184, 191, 217, 298, 318, 339...
# 2      [43, 80, 105, 115, 120, 130, 267, 268, 294, 35...
# 3      [80, 92, 95, 145, 175, 191, 216, 273, 294, 310...
# 4      [80, 114, 145, 211, 217, 294, 295, 369, 378, 3...
# ...                                                  ...
# 37897  [80, 99, 140, 271, 294, 310, 462, 527, 541, 65...
# 37898  [41, 80, 116, 127, 184, 191, 257, 262, 294, 34...
# 37899  [1, 47, 56, 80, 81, 101, 113, 115, 210, 250, 2...
# 37900  [1, 28, 41, 80, 115, 117, 283, 305, 378, 389, ...
# 37901  [1, 14, 80, 135, 165, 189, 197, 216, 283, 288,...
#
# [37902 rows x 9 columns]

# %% [markdown]
# ### Spliting COCONUT dataset

# %%
#Loading zinc database from csv 
suppl_coco = pd.read_csv('../data/COCOECFP.csv', delimiter = ' ')
suppl_coco
# Out:
#         Coconut_id                                             Smiles  \
# 0       CNP0000002  CC=C(N=CS)C(=O)OC1C(COC(C)=O)OC(C2(O)CC(=O)C(N...
# 1       CNP0000003  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(OC)c5c4C...
# 2       CNP0000004  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(OC)c5c4C...
# 3       CNP0000005  CC1(C)CC2C(OC(=O)c3ccccc3)C(OC(=O)c3ccccc3)CC(...
# 4       CNP0000006  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(O)c5c4C(...
# ...            ...                                                ...
# 386292  CNP0436851                        COc1cccc2ccc(C(C)=O)c(O)c12
# 386293  CNP0436852  COc1cc(OC)c2c(c1)C(OC)(c1ccc3c(c1O)C(=O)c1c(O)...
# 386294  CNP0436853  CC1(C)C=Cc2cc(C3COc4c5c(cc(O)c4C3=O)OC(C)(C)C=...
# 386295  CNP0436854  CCCCCCCC1CC(=O)NC(CO)C(=O)NC(CO)C(=O)N2CCCC2C(...
# 386296  CNP0436855  CCCCCCCC1CC(=O)NC(C(C)C)C(=O)NC(C(O)C(C)C)C(=O...
#
#                  MW     logP                        Inchi         Inchi_s  \
# 0        660.183639 -2.08210  FJEMIESGEMWDOB-UHFFFAOYSA-N  FJEMIESGEMWDOB
# 1        598.183897  3.63422  KLWKJVYCDFWQMK-UHFFFAOYSA-N  KLWKJVYCDFWQMK
# 2        554.157682  3.32262  PTEKHLCNKCAXPH-UHFFFAOYSA-N  PTEKHLCNKCAXPH
# 3        534.298139  6.87940  ZVAVQCZAGOKAMX-UHFFFAOYSA-N  ZVAVQCZAGOKAMX
# 4        540.142032  3.01962  UYIPOCQHTAYRMA-UHFFFAOYSA-N  UYIPOCQHTAYRMA
# ...             ...      ...                          ...             ...
# 386292   216.078644  2.75660  XNWOWNYWQOTWIX-UHFFFAOYSA-N  XNWOWNYWQOTWIX
# 386293   570.188983  4.77902  XWGVAZYMLDVIDS-UHFFFAOYSA-N  XWGVAZYMLDVIDS
# 386294   420.157288  4.82510  XZXMEYSQXQNHCX-UHFFFAOYSA-N  XZXMEYSQXQNHCX
# 386295  1183.685261 -1.20930  YNLIJTVZSFUHKP-UHFFFAOYSA-N  YNLIJTVZSFUHKP
# 386296  1456.817732 -3.86630  ZQEJMIHHZHRPMS-UHFFFAOYSA-N  ZQEJMIHHZHRPMS
#
#         Name                                               ECFP  \
# 0       COCO  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1       COCO  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2       COCO  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3       COCO  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4       COCO  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# ...      ...                                                ...
# 386292  COCO  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 386293  COCO  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 386294  COCO  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 386295  COCO  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 386296  COCO  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                                    Bitset
# 0       [39, 58, 80, 118, 140, 144, 147, 209, 229, 252...
# 1       [77, 94, 249, 314, 467, 495, 497, 569, 587, 64...
# 2       [77, 249, 298, 314, 352, 467, 497, 569, 587, 6...
# 3       [13, 70, 80, 114, 145, 147, 207, 270, 302, 341...
# 4       [77, 249, 298, 314, 352, 410, 457, 467, 497, 5...
# ...                                                   ...
# 386292  [67, 202, 203, 230, 249, 650, 695, 725, 806, 8...
# 386293  [5, 67, 84, 142, 148, 202, 206, 231, 249, 253,...
# 386294  [1, 6, 53, 56, 84, 212, 276, 294, 314, 398, 43...
# 386295  [1, 5, 19, 42, 80, 109, 115, 130, 222, 231, 23...
# 386296  [1, 5, 19, 42, 65, 80, 115, 140, 219, 222, 227...
#
# [386297 rows x 9 columns]

# %%
suppl_coco = suppl_coco.sample(frac=1).reset_index(drop=True)

# %%
suppl_coco.head()
# Out:
#    Coconut_id                                             Smiles           MW  \
# 0  CNP0248878  CC1(C)CCC2(C(=O)OC3OC(CO)C(O)C(O)C3O)CCC3(C)C(...  1072.545424
# 1  CNP0075371              CC1=C2C3OC(=O)C(C)C3CC(O)C2(C)C(O)CC1   266.151809
# 2  CNP0146446  COC(=O)C=CCCC(C)C(CC(OC)C(C)CCC(=O)C(C)C(CC=CN...   872.441903
# 3  CNP0223379  COc1cc2c(c(OC)c1OC)-c1ccc(NC(C)C(=O)NCCn3cnc4c...   599.274384
# 4  CNP0214728  CNC(=N)NC(CCO)c1c(C)cc2c(c1O)C(=O)c1c(OC3OC(CO...   696.287534
#
#       logP                        Inchi         Inchi_s  Name  \
# 0 -0.27470  YBIPDQXUUCFWRB-UHFFFAOYSA-N  YBIPDQXUUCFWRB  COCO
# 1  1.40620  SYPQXTIYYRZIRI-UHFFFAOYSA-N  SYPQXTIYYRZIRI  COCO
# 2  5.10940  RKELDRSBNPAPTP-UHFFFAOYSA-N  RKELDRSBNPAPTP  COCO
# 3  3.82950  FCCPPJJKPMTUAA-UHFFFAOYSA-N  FCCPPJJKPMTUAA  COCO
# 4 -0.77011  RJDGBORWDCRYMM-UHFFFAOYSA-O  RJDGBORWDCRYMM  COCO
#
#                                                 ECFP  \
# 0  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                               Bitset
# 0  [10, 22, 80, 155, 222, 249, 267, 282, 363, 389...
# 1  [110, 188, 192, 277, 314, 433, 438, 468, 622, ...
# 2  [1, 31, 52, 69, 80, 140, 183, 192, 200, 227, 2...
# 3  [1, 33, 45, 80, 184, 197, 232, 245, 249, 283, ...
# 4  [1, 39, 80, 104, 117, 202, 222, 273, 291, 298,...

# %%
df_split1 = np.array_split(suppl_coco, 10)

# %%
df_split1[1]
# Out:
#        Coconut_id                                             Smiles  \
# 38630  CNP0112088  COc1cc2c(c(O)c1CC=C(C)C)C(=O)CC(c1ccc(OC)c(OC)...
# 38631  CNP0159613                      NS(=O)(=O)c1ccc(C(=O)[O-])cc1
# 38632  CNP0035095  COC(=O)C(C)NC(=O)C1CN(S(=O)(=O)c2ccccc2)CCN1S(...
# 38633  CNP0109391  CCC(C)C1C(=O)OC(C(C)C)C(=O)N(C)C(C)C(=O)N(C)C(...
# 38634  CNP0070720  C=C(CCC(C)C1CCC2C3CC(O)C4(O)CC(O)CCC4(C)C3C(OC...
# ...           ...                                                ...
# 77255  CNP0289534        CCCCCCCCCCCC1=C(OB(O)O)C(=O)C=C(OB(O)O)C1=O
# 77256  CNP0278233  NC1=NC(=C2CCNC(=O)c3[nH]ccc32)C(=O)N1C(CNC(=O)...
# 77257  CNP0225520  CC(C)=CCCC(C)(OC1OC(COC2OC(CO)C(O)C(O)C2O)C(O)...
# 77258  CNP0146353                                   CCCCCCCCCCC=CC=O
# 77259  CNP0193326  CC=C(C)C(=O)OC1C(O)C(O)C2(C)C3C(=O)C=C(C)C2C3C...
#
#                MW    logP                        Inchi         Inchi_s  Name  \
# 38630  534.298139  7.8684  CLFBWSAWMMKPPY-UHFFFAOYSA-N  CLFBWSAWMMKPPY  COCO
# 38631  200.002302 -1.3025  UCAGLBKTLXCODC-UHFFFAOYSA-M  UCAGLBKTLXCODC  COCO
# 38632  495.113392  0.4281  KQYKSQYUXHKDEA-UHFFFAOYSA-N  KQYKSQYUXHKDEA  COCO
# 38633  974.677991  3.8375  QSZUTKACGNSKBA-UHFFFAOYSA-N  QSZUTKACGNSKBA  COCO
# 38634  490.365825  5.2620  VHARTKGGDFEJCI-UHFFFAOYSA-N  VHARTKGGDFEJCI  COCO
# ...           ...     ...                          ...             ...   ...
# 77255  382.197029  1.1693  JWQCLYPCCIERDR-UHFFFAOYSA-N  JWQCLYPCCIERDR  COCO
# 77256  554.113797  0.4534  WOUYWOYRNOEAKO-UHFFFAOYSA-N  WOUYWOYRNOEAKO  COCO
# 77257  800.492207  1.1214  VJVAKCNCJNSFPD-UHFFFAOYSA-N  VJVAKCNCJNSFPD  COCO
# 77258  196.182715  4.2723  VMUNAKQXJLHODT-UHFFFAOYSA-N  VMUNAKQXJLHODT  COCO
# 77259  348.193674  2.0235  HOXNGFVTRBWUMU-UHFFFAOYSA-N  HOXNGFVTRBWUMU  COCO
#
#                                                     ECFP  \
# 38630  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 38631  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 38632  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 38633  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 38634  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# ...                                                  ...
# 77255  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 77256  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 77257  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 77258  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 77259  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                                   Bitset
# 38630  [20, 80, 94, 101, 118, 202, 205, 218, 231, 249...
# 38631  [319, 350, 650, 715, 807, 833, 1128, 1171, 117...
# 38632  [1, 54, 117, 140, 143, 147, 211, 268, 283, 319...
# 38633  [1, 5, 19, 38, 42, 51, 80, 115, 160, 184, 219,...
# 38634  [1, 8, 29, 57, 80, 105, 155, 243, 277, 283, 31...
# ...                                                  ...
# 77255  [46, 80, 84, 110, 271, 294, 314, 355, 423, 591...
# 77256  [1, 60, 79, 80, 143, 155, 195, 197, 305, 314, ...
# 77257  [25, 80, 114, 170, 175, 222, 267, 392, 401, 47...
# 77258  [80, 83, 92, 294, 401, 432, 591, 639, 650, 694...
# 77259  [84, 141, 171, 175, 271, 307, 314, 321, 364, 5...
#
# [38630 rows x 9 columns]
