# %% [markdown]
# # Relative feature tightness omitting part 0 of dataset

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import csv
import numpy as np

from ast import literal_eval
import re
import sys
sys.path.insert(0,"./../fip3")
from fip import profiles

# %% [markdown]
# ## Dataset prep

# %% [markdown]
# ### Making feature pointwise mutual information profiles

# %%
profile1 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/COCONUT/COCOp1_38630.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=38630)
profile2 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/COCONUT/COCOp2_38630.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=38630)

# %%
profile3 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/COCONUT/COCOp3_38630.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=38630)

# %%
profile4 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/COCONUT/COCOp4_38630.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=38630)

# %%
profile5 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/COCONUT/COCOp5_38630.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=38630)

# %%
profile6 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/COCONUT/COCOp6_38630.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=38630)

# %%
profile7 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/COCONUT/COCOp7_38629.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=38629)

# %%
profile8 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/COCONUT/COCOp8_38629.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=38629)

# %%
profile9 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/COCONUT/COCOp9_38629.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=38629)

# %%
profile1.add_another_cooccurrence_profile(profile2)
profile1.add_another_cooccurrence_profile(profile3)
profile1.add_another_cooccurrence_profile(profile4)
profile1.add_another_cooccurrence_profile(profile5)
profile1.add_another_cooccurrence_profile(profile6)
profile1.add_another_cooccurrence_profile(profile7)
profile1.add_another_cooccurrence_profile(profile8)
profile1.add_another_cooccurrence_profile(profile9)
profile1.df
# Out:
#                    value
# feature1 feature2
# 0        0          3059
#          1          1040
#          10          134
#          100          45
#          1000         43
# ...                  ...
# 997      998           6
#          999          16
# 998      998        2840
#          999          90
# 999      999        6440
#
# [2095371 rows x 1 columns]

# %%
probability_profile = profiles.CooccurrenceProbabilityProfile.from_cooccurrence_profile(profile1)
probability_profile.df
# Out:
#                       value
# feature1 feature2
# 0        0         0.008799
#          1         0.002991
#          10        0.000385
#          100       0.000129
#          1000      0.000124
# ...                     ...
# 997      998       0.000017
#          999       0.000046
# 998      998       0.008169
#          999       0.000259
# 999      999       0.018523
#
# [2095371 rows x 1 columns]

# %%
pmi_profile = profiles.PointwiseMutualInformationProfile.from_cooccurrence_probability_profile(probability_profile)
pmi_profile

# %%
reference_profile1 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/ZINC/ZINCp1_37902.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=37902)
reference_profile2 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/ZINC/ZINCp2_37901.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=37901)
reference_profile3 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/ZINC/ZINCp3_37901.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=37901)
reference_profile4 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/ZINC/ZINCp4_37901.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=37901)
reference_profile5 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/ZINC/ZINCp5_37901.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=37901)
reference_profile6 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/ZINC/ZINCp6_37901.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=37901)
reference_profile7 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/ZINC/ZINCp7_37901.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=37901)
reference_profile8 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/ZINC/ZINCp8_37901.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=37901)
reference_profile9 = profiles.CooccurrenceProfile.from_dataframe(pd.read_csv('../data/CP1/ZINC/ZINCp9_37901.csv', dtype={'feature1': 'str','feature2' : 'str' }), vector_count=37901)

# %%
reference_profile1.add_another_cooccurrence_profile(reference_profile2)
reference_profile1.add_another_cooccurrence_profile(reference_profile3)
reference_profile1.add_another_cooccurrence_profile(reference_profile4)
reference_profile1.add_another_cooccurrence_profile(reference_profile5)
reference_profile1.add_another_cooccurrence_profile(reference_profile6)
reference_profile1.add_another_cooccurrence_profile(reference_profile7)
reference_profile1.add_another_cooccurrence_profile(reference_profile8)
reference_profile1.add_another_cooccurrence_profile(reference_profile9)
reference_profile1.df
# Out:
#                    value
# feature1 feature2
# 0        0           733
#          1           138
#          10            6
#          1000          3
#          1001          3
# ...                  ...
# 997      998          15
#          999          37
# 998      998        2514
#          999          55
# 999      999        4056
#
# [2073234 rows x 1 columns]

# %%
reference_probability_profile = profiles.CooccurrenceProbabilityProfile.from_cooccurrence_profile(reference_profile1)
reference_probability_profile.df
# Out:
#                       value
# feature1 feature2
# 0        0         0.002149
#          1         0.000405
#          10        0.000018
#          1000      0.000009
#          1001      0.000009
# ...                     ...
# 997      998       0.000044
#          999       0.000108
# 998      998       0.007370
#          999       0.000161
# 999      999       0.011891
#
# [2073234 rows x 1 columns]

# %%
reference_pmi_profile = profiles.PointwiseMutualInformationProfile.from_cooccurrence_probability_profile(reference_probability_profile)
reference_pmi_profile

# %% [markdown]
# ### Making feature pointwise KL divergence profile between COCONUT and ZINC

# %%
difference_pkld_profile = profiles.PointwiseKLDivergenceProfile.from_cooccurrence_probability_profiles(
    probability_profile, reference_probability_profile)
difference_pkld_profile.df
# Out:
#                       value
# feature1 feature2
# 0        0         2.033706
#          1         2.886374
#          10        4.453658
#          100       5.464388
#          1000      3.813833
# ...                     ...
# 939      986      -1.027473
# 959      995      -0.027473
# 968      990      -3.834828
# 969      995      -0.027473
# 977      995      -3.486905
#
# [2097992 rows x 1 columns]

# %% [markdown]
# ### Sampling structures from COCONUT and ZINC datasets

# %%
coconut_samples = pd.read_csv('../data/CP1/COCONUT/COCOrandom.csv', delimiter = ' ')
coconut_samples = coconut_samples.drop(['Coconut_id'], axis=1)
coconut_samples['Name'] = 'COCONUT'
coconut_samples
# Out:
#                                                    Smiles          MW  \
# 0                                CCCCCC1C(=O)CCC1CC(=O)OC  226.156895
# 1         Cc1c2c(cc3c1oc(=O)c1ccccc13)CN(c1cccc(Cl)c1)CO2  377.081871
# 2       COc1cc(C2CC(=O)Oc3ccc4c(=O)c(-c5ccccc5)coc4c32...  458.136553
# 3              C=C1C(=O)OC2C=C(CO)CCC(OCC)C3=CC(OC3=O)C12  320.125988
# 4       CC(=O)C(CC=C(C)C)C(C)=CCOc1ccc(CCNC(=O)c2ccccc...  419.246044
# ...                                                   ...         ...
# 386292  COC(=O)C1=COC(OC2OC(COC(=O)c3ccc(O)c(OC)c3)C(O...  554.163556
# 386293  Cc1c(CCC(=O)NCC(=O)NCC(=O)[O-])c(=O)oc2cc(O)c(...  395.065152
# 386294  CC(=O)Oc1c(C)cc2c(c1O)C(=O)C(C1=CC(=O)c3cc(C)c...  490.089997
# 386295  C[N+]([O-])=NCOC1OC(CO)C(O)C(OC2OC(COC3OC(CO)C...  576.201398
# 386296    CCCC1OC(CC(=O)O)CC2(O)C(=O)c3cccc(O)c3C(=O)C12O  364.115818
#
#            logP                        Inchi         Inchi_s     Name  \
# 0       2.72510  KVWWIYGFBYDJQC-UHFFFAOYSA-N  KVWWIYGFBYDJQC  COCONUT
# 1       5.26452  DWNKYEMDZRSBHK-UHFFFAOYSA-N  DWNKYEMDZRSBHK  COCONUT
# 2       4.92680  ZRAWZNDFONIPGO-UHFFFAOYSA-N  ZRAWZNDFONIPGO  COCONUT
# 3       1.05360  PTJPAEBQCZMNAV-UHFFFAOYSA-N  PTJPAEBQCZMNAV  COCONUT
# 4       5.54570  FGXBFPFGWRVMGG-UHFFFAOYSA-N  FGXBFPFGWRVMGG  COCONUT
# ...         ...                          ...             ...      ...
# 386292 -0.63720  LIVSNGMPJUCRLO-UHFFFAOYSA-N  LIVSNGMPJUCRLO  COCONUT
# 386293 -0.62468  SSZVGMXOKPZNCV-UHFFFAOYSA-M  SSZVGMXOKPZNCV  COCONUT
# 386294  2.87624  JODPOMYHTFZNTK-UHFFFAOYSA-N  JODPOMYHTFZNTK  COCONUT
# 386295 -6.99890  STHHNNUYQQUJGY-UHFFFAOYSA-N  STHHNNUYQQUJGY  COCONUT
# 386296  0.66570  XDYYASNFOIEXFT-UHFFFAOYSA-N  XDYYASNFOIEXFT  COCONUT
#
#                                                      ECFP  \
# 0       <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1       <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2       <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3       <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4       <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# ...                                                   ...
# 386292  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 386293  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 386294  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 386295  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 386296  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                                    Bitset
# 0       [80, 142, 195, 226, 294, 314, 334, 339, 370, 5...
# 1       [133, 137, 165, 216, 252, 314, 350, 382, 398, ...
# 2       [45, 60, 133, 145, 222, 227, 231, 249, 282, 28...
# 3       [35, 80, 176, 222, 294, 314, 408, 514, 650, 65...
# 4       [1, 8, 80, 102, 197, 265, 310, 322, 367, 389, ...
# ...                                                   ...
# 386292  [58, 80, 145, 147, 167, 231, 233, 249, 314, 42...
# 386293  [41, 80, 197, 252, 254, 305, 314, 366, 406, 42...
# 386294  [16, 39, 84, 202, 224, 314, 333, 352, 516, 641...
# 386295  [77, 80, 170, 222, 349, 443, 489, 588, 610, 65...
# 386296  [80, 194, 294, 298, 314, 352, 389, 490, 492, 5...
#
# [386297 rows x 8 columns]

# %%
df_split_coco = np.array_split(coconut_samples, 10)

# %%
df_split_coco[0]
# Out:
#                                                   Smiles          MW     logP  \
# 0                               CCCCCC1C(=O)CCC1CC(=O)OC  226.156895  2.72510
# 1        Cc1c2c(cc3c1oc(=O)c1ccccc13)CN(c1cccc(Cl)c1)CO2  377.081871  5.26452
# 2      COc1cc(C2CC(=O)Oc3ccc4c(=O)c(-c5ccccc5)coc4c32...  458.136553  4.92680
# 3             C=C1C(=O)OC2C=C(CO)CCC(OCC)C3=CC(OC3=O)C12  320.125988  1.05360
# 4      CC(=O)C(CC=C(C)C)C(C)=CCOc1ccc(CCNC(=O)c2ccccc...  419.246044  5.54570
# ...                                                  ...         ...      ...
# 38625  COc1cc(C2OC3(c4cc(OC)c5c(c4)OCO5)OC3(C)C2C)cc2...  414.131468  3.51050
# 38626  O=C(OCC1OC(Oc2c(C(=O)O)ccc(O)c2O)C(O)C(O)C1O)c...  484.085305 -1.04380
# 38627                            COc1cc(O)c2oc(=O)ccc2c1  192.042259  1.50720
# 38628  Cc1cc(O)cc(O)c1C(=O)OC1CC2(C)C3C(C=C(CO)C12O)C...  418.199153  2.02822
# 38629         COc1ccc(Oc2cc(=O)c3c(O)c(OC)c(O)cc3o2)cc1O  346.068867  2.71930
#
#                              Inchi         Inchi_s     Name  \
# 0      KVWWIYGFBYDJQC-UHFFFAOYSA-N  KVWWIYGFBYDJQC  COCONUT
# 1      DWNKYEMDZRSBHK-UHFFFAOYSA-N  DWNKYEMDZRSBHK  COCONUT
# 2      ZRAWZNDFONIPGO-UHFFFAOYSA-N  ZRAWZNDFONIPGO  COCONUT
# 3      PTJPAEBQCZMNAV-UHFFFAOYSA-N  PTJPAEBQCZMNAV  COCONUT
# 4      FGXBFPFGWRVMGG-UHFFFAOYSA-N  FGXBFPFGWRVMGG  COCONUT
# ...                            ...             ...      ...
# 38625  CVGWCATWCAZNFN-UHFFFAOYSA-N  CVGWCATWCAZNFN  COCONUT
# 38626  MANZFHVJGHCTOA-UHFFFAOYSA-N  MANZFHVJGHCTOA  COCONUT
# 38627  FWYIBGHGBOVPNL-UHFFFAOYSA-N  FWYIBGHGBOVPNL  COCONUT
# 38628  SWVWDNGFQHDELB-UHFFFAOYSA-N  SWVWDNGFQHDELB  COCONUT
# 38629  MEVADFZPXVBPPE-UHFFFAOYSA-N  MEVADFZPXVBPPE  COCONUT
#
#                                                     ECFP  \
# 0      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# ...                                                  ...
# 38625  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 38626  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 38627  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 38628  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 38629  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                                   Bitset
# 0      [80, 142, 195, 226, 294, 314, 334, 339, 370, 5...
# 1      [133, 137, 165, 216, 252, 314, 350, 382, 398, ...
# 2      [45, 60, 133, 145, 222, 227, 231, 249, 282, 28...
# 3      [35, 80, 176, 222, 294, 314, 408, 514, 650, 65...
# 4      [1, 8, 80, 102, 197, 265, 310, 322, 367, 389, ...
# ...                                                  ...
# 38625  [117, 227, 230, 249, 441, 551, 556, 656, 695, ...
# 38626  [58, 67, 80, 125, 145, 147, 202, 233, 333, 389...
# 38627  [133, 203, 239, 314, 322, 650, 656, 695, 745, ...
# 38628  [80, 145, 167, 222, 249, 279, 384, 432, 482, 5...
# 38629  [40, 94, 202, 249, 254, 314, 322, 333, 501, 62...
#
# [38630 rows x 8 columns]

# %%
zinc_samples = pd.read_csv('../data/CP1/ZINC/ZINCrandom.csv', delimiter = ' ')
zinc_samples = zinc_samples.drop(['Zinc_id'], axis=1)
zinc_samples
# Out:
#                                                    Smiles          MW  \
# 0       Cc1ccc(-n2c(=O)c3c(n4c(SCCc5ccccc5)nnc24)-c2cc...  532.229683
# 1       Cc1ccc(-n2c(COc3ccccc3)nnc2SCC(=O)Nc2ccc3c(c2)...  488.151826
# 2       COCCNS(=O)(=O)c1ccc(OCC(=O)N2CCC(C(N)=O)CC2)c(...  433.107434
# 3       Cc1ccc(S(=O)(=O)n2nc(NCc3cccc(Br)c3)nc2NCc2ccc...  588.978270
# 4              CCn1c(-c2ccccc2)c(C)s/c1=N\C(=O)c1ccccc1Br  400.024496
# ...                                                   ...         ...
# 379007  CCOC(=O)C1=C(C)N=c2s/c(=C\c3ccc(OCC)c(OC)c3)c(...  478.156243
# 379008  CCCCOc1ccc(-c2nn(-c3ccccc3)cc2CNC(=O)c2ccc(OCC...  501.242770
# 379009  CNc1cc([C@H]2CCCN(Cc3cccc(C)c3)C2)nc(-c2cccnc2)n1  373.226646
# 379010  COc1ccc(C23CC4CC(CC(C4)C2)C3)cc1C(=O)NC(c1cccc...  451.251129
# 379011                         O=C(O)[C@H]1CCS(=O)(=O)CN1  179.025229
#
#            logP                        Inchi         Inchi_s  Name  \
# 0       6.94842  DPUIXUVMXJXCJR-UHFFFAOYSA-N  DPUIXUVMXJXCJR  ZINC
# 1       4.65672  HVIYVAXZIXJRQC-UHFFFAOYSA-N  HVIYVAXZIXJRQC  ZINC
# 2       0.36740  RAILYSNQBZZKMQ-UHFFFAOYSA-N  RAILYSNQBZZKMQ  ZINC
# 3       5.57272  FFUQFTXMHIMSHO-UHFFFAOYSA-N  FFUQFTXMHIMSHO  ZINC
# 4       5.04852  GMWZBJMZXGQSQF-VZCXRCSSSA-N  GMWZBJMZXGQSQF  ZINC
# ...         ...                          ...             ...   ...
# 379007  3.20560  NKVUPLXRBGDCKZ-FQWPPLDYSA-N  NKVUPLXRBGDCKZ  ZINC
# 379008  6.57610  GRVSBYRYFLOHAZ-UHFFFAOYSA-N  GRVSBYRYFLOHAZ  ZINC
# 379009  4.26832  WGJHTUZEMVLXOF-FQEVSTJZSA-N  WGJHTUZEMVLXOF  ZINC
# 379010  6.68240  GUGKIBFTNCSUKM-UHFFFAOYSA-N  GUGKIBFTNCSUKM  ZINC
# 379011 -1.19480  HVHWJEAZLNXDAE-SCSAIBSYSA-N  HVHWJEAZLNXDAE  ZINC
#
#                                                      ECFP  \
# 0       <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1       <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2       <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3       <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4       <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# ...                                                   ...
# 379007  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 379008  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 379009  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 379010  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 379011  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                                    Bitset
# 0       [2, 58, 74, 80, 105, 116, 153, 233, 235, 289, ...
# 1       [41, 58, 80, 102, 116, 127, 184, 191, 233, 235...
# 2       [13, 80, 94, 111, 140, 198, 222, 279, 317, 319...
# 3       [80, 82, 92, 157, 235, 255, 319, 350, 374, 378...
# 4       [30, 34, 57, 80, 162, 289, 294, 308, 313, 351,...
# ...                                                   ...
# 379007  [25, 80, 94, 125, 145, 147, 162, 237, 249, 281...
# 379008  [13, 76, 80, 94, 102, 197, 255, 265, 294, 322,...
# 379009  [80, 105, 257, 378, 437, 446, 736, 739, 744, 7...
# 379010  [1, 46, 94, 117, 235, 249, 389, 484, 486, 556,...
# 379011  [74, 148, 207, 362, 389, 469, 552, 553, 650, 8...
#
# [379012 rows x 8 columns]

# %%
df_split_zinc = np.array_split(zinc_samples, 10)
df_split_zinc[0]
# Out:
#                                                   Smiles          MW     logP  \
# 0      Cc1ccc(-n2c(=O)c3c(n4c(SCCc5ccccc5)nnc24)-c2cc...  532.229683  6.94842
# 1      Cc1ccc(-n2c(COc3ccccc3)nnc2SCC(=O)Nc2ccc3c(c2)...  488.151826  4.65672
# 2      COCCNS(=O)(=O)c1ccc(OCC(=O)N2CCC(C(N)=O)CC2)c(...  433.107434  0.36740
# 3      Cc1ccc(S(=O)(=O)n2nc(NCc3cccc(Br)c3)nc2NCc2ccc...  588.978270  5.57272
# 4             CCn1c(-c2ccccc2)c(C)s/c1=N\C(=O)c1ccccc1Br  400.024496  5.04852
# ...                                                  ...         ...      ...
# 37897  Cc1ccc(Cl)cc1N1CCN(C(=O)CN(c2ccc(Cl)c(Cl)c2)S(...  551.060396  5.49932
# 37898  COc1ccc(S(=O)(=O)N2CCC[C@H](C(=O)NCCCN3CCOCC3)...  425.198442  0.93440
# 37899  Cc1ccc(CN2C(=O)S/C(=C\c3cccn3-c3ccc(N(C)C)cc3)...  417.151098  5.08822
# 37900          CC(C)(C)C(=O)N1CC[C@H](Oc2cccc3cccnc23)C1  298.168128  3.26060
# 37901  CC[C@@H](NC(=O)[C@H]1CCCN(S(=O)(=O)c2cccs2)C1)...  420.154135  4.03314
#
#                              Inchi         Inchi_s  Name  \
# 0      DPUIXUVMXJXCJR-UHFFFAOYSA-N  DPUIXUVMXJXCJR  ZINC
# 1      HVIYVAXZIXJRQC-UHFFFAOYSA-N  HVIYVAXZIXJRQC  ZINC
# 2      RAILYSNQBZZKMQ-UHFFFAOYSA-N  RAILYSNQBZZKMQ  ZINC
# 3      FFUQFTXMHIMSHO-UHFFFAOYSA-N  FFUQFTXMHIMSHO  ZINC
# 4      GMWZBJMZXGQSQF-VZCXRCSSSA-N  GMWZBJMZXGQSQF  ZINC
# ...                            ...             ...   ...
# 37897  UEZQAXBXQIVHHC-UHFFFAOYSA-N  UEZQAXBXQIVHHC  ZINC
# 37898  SERMPMMEGHANCD-KRWDZBQOSA-N  SERMPMMEGHANCD  ZINC
# 37899  CPCJMIHIVOAJEG-JCMHNJIXSA-N  CPCJMIHIVOAJEG  ZINC
# 37900  JTLGIMMFHQVTQX-AWEZNQCLSA-N  JTLGIMMFHQVTQX  ZINC
# 37901  QKVQUQDHISLTBK-RBUKOAKNSA-N  QKVQUQDHISLTBK  ZINC
#
#                                                     ECFP  \
# 0      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# ...                                                  ...
# 37897  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 37898  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 37899  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 37900  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 37901  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                                   Bitset
# 0      [2, 58, 74, 80, 105, 116, 153, 233, 235, 289, ...
# 1      [41, 58, 80, 102, 116, 127, 184, 191, 233, 235...
# 2      [13, 80, 94, 111, 140, 198, 222, 279, 317, 319...
# 3      [80, 82, 92, 157, 235, 255, 319, 350, 374, 378...
# 4      [30, 34, 57, 80, 162, 289, 294, 308, 313, 351,...
# ...                                                  ...
# 37897  [24, 80, 165, 216, 231, 319, 350, 365, 366, 38...
# 37898  [80, 93, 197, 221, 319, 322, 350, 374, 446, 52...
# 37899  [74, 80, 95, 233, 235, 273, 281, 310, 314, 475...
# 37900  [114, 119, 145, 270, 378, 392, 448, 449, 524, ...
# 37901  [1, 14, 80, 117, 241, 291, 294, 350, 383, 446,...
#
# [37902 rows x 8 columns]

# %%
joint_samples = pd.concat((df_split_coco[0], df_split_zinc[0]), ignore_index=True)

# %%
joint_samples
# Out:
#                                                   Smiles          MW     logP  \
# 0                               CCCCCC1C(=O)CCC1CC(=O)OC  226.156895  2.72510
# 1        Cc1c2c(cc3c1oc(=O)c1ccccc13)CN(c1cccc(Cl)c1)CO2  377.081871  5.26452
# 2      COc1cc(C2CC(=O)Oc3ccc4c(=O)c(-c5ccccc5)coc4c32...  458.136553  4.92680
# 3             C=C1C(=O)OC2C=C(CO)CCC(OCC)C3=CC(OC3=O)C12  320.125988  1.05360
# 4      CC(=O)C(CC=C(C)C)C(C)=CCOc1ccc(CCNC(=O)c2ccccc...  419.246044  5.54570
# ...                                                  ...         ...      ...
# 76527  Cc1ccc(Cl)cc1N1CCN(C(=O)CN(c2ccc(Cl)c(Cl)c2)S(...  551.060396  5.49932
# 76528  COc1ccc(S(=O)(=O)N2CCC[C@H](C(=O)NCCCN3CCOCC3)...  425.198442  0.93440
# 76529  Cc1ccc(CN2C(=O)S/C(=C\c3cccn3-c3ccc(N(C)C)cc3)...  417.151098  5.08822
# 76530          CC(C)(C)C(=O)N1CC[C@H](Oc2cccc3cccnc23)C1  298.168128  3.26060
# 76531  CC[C@@H](NC(=O)[C@H]1CCCN(S(=O)(=O)c2cccs2)C1)...  420.154135  4.03314
#
#                              Inchi         Inchi_s     Name  \
# 0      KVWWIYGFBYDJQC-UHFFFAOYSA-N  KVWWIYGFBYDJQC  COCONUT
# 1      DWNKYEMDZRSBHK-UHFFFAOYSA-N  DWNKYEMDZRSBHK  COCONUT
# 2      ZRAWZNDFONIPGO-UHFFFAOYSA-N  ZRAWZNDFONIPGO  COCONUT
# 3      PTJPAEBQCZMNAV-UHFFFAOYSA-N  PTJPAEBQCZMNAV  COCONUT
# 4      FGXBFPFGWRVMGG-UHFFFAOYSA-N  FGXBFPFGWRVMGG  COCONUT
# ...                            ...             ...      ...
# 76527  UEZQAXBXQIVHHC-UHFFFAOYSA-N  UEZQAXBXQIVHHC     ZINC
# 76528  SERMPMMEGHANCD-KRWDZBQOSA-N  SERMPMMEGHANCD     ZINC
# 76529  CPCJMIHIVOAJEG-JCMHNJIXSA-N  CPCJMIHIVOAJEG     ZINC
# 76530  JTLGIMMFHQVTQX-AWEZNQCLSA-N  JTLGIMMFHQVTQX     ZINC
# 76531  QKVQUQDHISLTBK-RBUKOAKNSA-N  QKVQUQDHISLTBK     ZINC
#
#                                                     ECFP  \
# 0      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# ...                                                  ...
# 76527  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76528  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76529  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76530  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76531  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                                   Bitset
# 0      [80, 142, 195, 226, 294, 314, 334, 339, 370, 5...
# 1      [133, 137, 165, 216, 252, 314, 350, 382, 398, ...
# 2      [45, 60, 133, 145, 222, 227, 231, 249, 282, 28...
# 3      [35, 80, 176, 222, 294, 314, 408, 514, 650, 65...
# 4      [1, 8, 80, 102, 197, 265, 310, 322, 367, 389, ...
# ...                                                  ...
# 76527  [24, 80, 165, 216, 231, 319, 350, 365, 366, 38...
# 76528  [80, 93, 197, 221, 319, 322, 350, 374, 446, 52...
# 76529  [74, 80, 95, 233, 235, 273, 281, 310, 314, 475...
# 76530  [114, 119, 145, 270, 378, 392, 448, 449, 524, ...
# 76531  [1, 14, 80, 117, 241, 291, 294, 350, 383, 446,...
#
# [76532 rows x 8 columns]

# %%
for x in joint_samples.index:
    a = joint_samples['Bitset'][x]
    a = a.split(", ")
    a = re.sub('\[', '', str(a))
    a = re.sub('\]', '', str(a))
    tup = literal_eval(a)
    joint_samples['Bitset'][x] = tup
# Out:
# /var/tmp/pbs.43231.lich-compute.vscht.cz/ipykernel_46004/3101749155.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   joint_samples['Bitset'][x] = tup

# %%
joint_samples
# Out:
#                                                   Smiles          MW     logP  \
# 0                               CCCCCC1C(=O)CCC1CC(=O)OC  226.156895  2.72510
# 1        Cc1c2c(cc3c1oc(=O)c1ccccc13)CN(c1cccc(Cl)c1)CO2  377.081871  5.26452
# 2      COc1cc(C2CC(=O)Oc3ccc4c(=O)c(-c5ccccc5)coc4c32...  458.136553  4.92680
# 3             C=C1C(=O)OC2C=C(CO)CCC(OCC)C3=CC(OC3=O)C12  320.125988  1.05360
# 4      CC(=O)C(CC=C(C)C)C(C)=CCOc1ccc(CCNC(=O)c2ccccc...  419.246044  5.54570
# ...                                                  ...         ...      ...
# 76527  Cc1ccc(Cl)cc1N1CCN(C(=O)CN(c2ccc(Cl)c(Cl)c2)S(...  551.060396  5.49932
# 76528  COc1ccc(S(=O)(=O)N2CCC[C@H](C(=O)NCCCN3CCOCC3)...  425.198442  0.93440
# 76529  Cc1ccc(CN2C(=O)S/C(=C\c3cccn3-c3ccc(N(C)C)cc3)...  417.151098  5.08822
# 76530          CC(C)(C)C(=O)N1CC[C@H](Oc2cccc3cccnc23)C1  298.168128  3.26060
# 76531  CC[C@@H](NC(=O)[C@H]1CCCN(S(=O)(=O)c2cccs2)C1)...  420.154135  4.03314
#
#                              Inchi         Inchi_s     Name  \
# 0      KVWWIYGFBYDJQC-UHFFFAOYSA-N  KVWWIYGFBYDJQC  COCONUT
# 1      DWNKYEMDZRSBHK-UHFFFAOYSA-N  DWNKYEMDZRSBHK  COCONUT
# 2      ZRAWZNDFONIPGO-UHFFFAOYSA-N  ZRAWZNDFONIPGO  COCONUT
# 3      PTJPAEBQCZMNAV-UHFFFAOYSA-N  PTJPAEBQCZMNAV  COCONUT
# 4      FGXBFPFGWRVMGG-UHFFFAOYSA-N  FGXBFPFGWRVMGG  COCONUT
# ...                            ...             ...      ...
# 76527  UEZQAXBXQIVHHC-UHFFFAOYSA-N  UEZQAXBXQIVHHC     ZINC
# 76528  SERMPMMEGHANCD-KRWDZBQOSA-N  SERMPMMEGHANCD     ZINC
# 76529  CPCJMIHIVOAJEG-JCMHNJIXSA-N  CPCJMIHIVOAJEG     ZINC
# 76530  JTLGIMMFHQVTQX-AWEZNQCLSA-N  JTLGIMMFHQVTQX     ZINC
# 76531  QKVQUQDHISLTBK-RBUKOAKNSA-N  QKVQUQDHISLTBK     ZINC
#
#                                                     ECFP  \
# 0      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# ...                                                  ...
# 76527  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76528  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76529  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76530  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76531  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                                   Bitset
# 0      (80, 142, 195, 226, 294, 314, 334, 339, 370, 5...
# 1      (133, 137, 165, 216, 252, 314, 350, 382, 398, ...
# 2      (45, 60, 133, 145, 222, 227, 231, 249, 282, 28...
# 3      (35, 80, 176, 222, 294, 314, 408, 514, 650, 65...
# 4      (1, 8, 80, 102, 197, 265, 310, 322, 367, 389, ...
# ...                                                  ...
# 76527  (24, 80, 165, 216, 231, 319, 350, 365, 366, 38...
# 76528  (80, 93, 197, 221, 319, 322, 350, 374, 446, 52...
# 76529  (74, 80, 95, 233, 235, 273, 281, 310, 314, 475...
# 76530  (114, 119, 145, 270, 378, 392, 448, 449, 524, ...
# 76531  (1, 14, 80, 117, 241, 291, 294, 350, 383, 446,...
#
# [76532 rows x 8 columns]

# %% [markdown]
# ## Relative feature tightness against a PMI interrelation profile

# %%
joint_samples['RFT'] = joint_samples['Bitset'].apply(
    lambda x: difference_pkld_profile.relative_feature_divergence(x))
joint_samples
# Out:
#                                                   Smiles          MW     logP  \
# 0                               CCCCCC1C(=O)CCC1CC(=O)OC  226.156895  2.72510
# 1        Cc1c2c(cc3c1oc(=O)c1ccccc13)CN(c1cccc(Cl)c1)CO2  377.081871  5.26452
# 2      COc1cc(C2CC(=O)Oc3ccc4c(=O)c(-c5ccccc5)coc4c32...  458.136553  4.92680
# 3             C=C1C(=O)OC2C=C(CO)CCC(OCC)C3=CC(OC3=O)C12  320.125988  1.05360
# 4      CC(=O)C(CC=C(C)C)C(C)=CCOc1ccc(CCNC(=O)c2ccccc...  419.246044  5.54570
# ...                                                  ...         ...      ...
# 76527  Cc1ccc(Cl)cc1N1CCN(C(=O)CN(c2ccc(Cl)c(Cl)c2)S(...  551.060396  5.49932
# 76528  COc1ccc(S(=O)(=O)N2CCC[C@H](C(=O)NCCCN3CCOCC3)...  425.198442  0.93440
# 76529  Cc1ccc(CN2C(=O)S/C(=C\c3cccn3-c3ccc(N(C)C)cc3)...  417.151098  5.08822
# 76530          CC(C)(C)C(=O)N1CC[C@H](Oc2cccc3cccnc23)C1  298.168128  3.26060
# 76531  CC[C@@H](NC(=O)[C@H]1CCCN(S(=O)(=O)c2cccs2)C1)...  420.154135  4.03314
#
#                              Inchi         Inchi_s     Name  \
# 0      KVWWIYGFBYDJQC-UHFFFAOYSA-N  KVWWIYGFBYDJQC  COCONUT
# 1      DWNKYEMDZRSBHK-UHFFFAOYSA-N  DWNKYEMDZRSBHK  COCONUT
# 2      ZRAWZNDFONIPGO-UHFFFAOYSA-N  ZRAWZNDFONIPGO  COCONUT
# 3      PTJPAEBQCZMNAV-UHFFFAOYSA-N  PTJPAEBQCZMNAV  COCONUT
# 4      FGXBFPFGWRVMGG-UHFFFAOYSA-N  FGXBFPFGWRVMGG  COCONUT
# ...                            ...             ...      ...
# 76527  UEZQAXBXQIVHHC-UHFFFAOYSA-N  UEZQAXBXQIVHHC     ZINC
# 76528  SERMPMMEGHANCD-KRWDZBQOSA-N  SERMPMMEGHANCD     ZINC
# 76529  CPCJMIHIVOAJEG-JCMHNJIXSA-N  CPCJMIHIVOAJEG     ZINC
# 76530  JTLGIMMFHQVTQX-AWEZNQCLSA-N  JTLGIMMFHQVTQX     ZINC
# 76531  QKVQUQDHISLTBK-RBUKOAKNSA-N  QKVQUQDHISLTBK     ZINC
#
#                                                     ECFP  \
# 0      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# ...                                                  ...
# 76527  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76528  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76529  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76530  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76531  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                                   Bitset       RFT
# 0      (80, 142, 195, 226, 294, 314, 334, 339, 370, 5...  1.717874
# 1      (133, 137, 165, 216, 252, 314, 350, 382, 398, ...  0.820610
# 2      (45, 60, 133, 145, 222, 227, 231, 249, 282, 28...  1.794547
# 3      (35, 80, 176, 222, 294, 314, 408, 514, 650, 65...  1.975365
# 4      (1, 8, 80, 102, 197, 265, 310, 322, 367, 389, ...  0.439023
# ...                                                  ...       ...
# 76527  (24, 80, 165, 216, 231, 319, 350, 365, 366, 38... -1.881786
# 76528  (80, 93, 197, 221, 319, 322, 350, 374, 446, 52... -1.244183
# 76529  (74, 80, 95, 233, 235, 273, 281, 310, 314, 475... -1.441439
# 76530  (114, 119, 145, 270, 378, 392, 448, 449, 524, ... -0.433078
# 76531  (1, 14, 80, 117, 241, 291, 294, 350, 383, 446,... -1.100593
#
# [76532 rows x 9 columns]

# %%
a4_dims = (11.7, 8.27)
sns.set_style("darkgrid")
fig, ax = plt.subplots(figsize=a4_dims)
sns.histplot(joint_samples, x='RFT', hue='Name')
plt.title('Relative feature tightness against a PMI interrelation profile 0')
plt.savefig(f"../images//joint_samples_RFT0.svg", format="svg")

# %% [markdown]
# According to the histogram, there is a visible split between Relative feature tightness distribution against the pointwise KL divergence profile between COCONUT and ZINC datasets, based on their radius 2 fragments. Larger fragments might diverge even further.

# %% [markdown]
# ### ROC CURVE

# %%
import numpy as np
from sklearn import metrics
import numpy as np
import matplotlib.pyplot as plt
from itertools import cycle

from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from sklearn.metrics import roc_auc_score

# %%
joint_samples
# Out:
#                                                   Smiles          MW     logP  \
# 0                               CCCCCC1C(=O)CCC1CC(=O)OC  226.156895  2.72510
# 1        Cc1c2c(cc3c1oc(=O)c1ccccc13)CN(c1cccc(Cl)c1)CO2  377.081871  5.26452
# 2      COc1cc(C2CC(=O)Oc3ccc4c(=O)c(-c5ccccc5)coc4c32...  458.136553  4.92680
# 3             C=C1C(=O)OC2C=C(CO)CCC(OCC)C3=CC(OC3=O)C12  320.125988  1.05360
# 4      CC(=O)C(CC=C(C)C)C(C)=CCOc1ccc(CCNC(=O)c2ccccc...  419.246044  5.54570
# ...                                                  ...         ...      ...
# 76527  Cc1ccc(Cl)cc1N1CCN(C(=O)CN(c2ccc(Cl)c(Cl)c2)S(...  551.060396  5.49932
# 76528  COc1ccc(S(=O)(=O)N2CCC[C@H](C(=O)NCCCN3CCOCC3)...  425.198442  0.93440
# 76529  Cc1ccc(CN2C(=O)S/C(=C\c3cccn3-c3ccc(N(C)C)cc3)...  417.151098  5.08822
# 76530          CC(C)(C)C(=O)N1CC[C@H](Oc2cccc3cccnc23)C1  298.168128  3.26060
# 76531  CC[C@@H](NC(=O)[C@H]1CCCN(S(=O)(=O)c2cccs2)C1)...  420.154135  4.03314
#
#                              Inchi         Inchi_s     Name  \
# 0      KVWWIYGFBYDJQC-UHFFFAOYSA-N  KVWWIYGFBYDJQC  COCONUT
# 1      DWNKYEMDZRSBHK-UHFFFAOYSA-N  DWNKYEMDZRSBHK  COCONUT
# 2      ZRAWZNDFONIPGO-UHFFFAOYSA-N  ZRAWZNDFONIPGO  COCONUT
# 3      PTJPAEBQCZMNAV-UHFFFAOYSA-N  PTJPAEBQCZMNAV  COCONUT
# 4      FGXBFPFGWRVMGG-UHFFFAOYSA-N  FGXBFPFGWRVMGG  COCONUT
# ...                            ...             ...      ...
# 76527  UEZQAXBXQIVHHC-UHFFFAOYSA-N  UEZQAXBXQIVHHC     ZINC
# 76528  SERMPMMEGHANCD-KRWDZBQOSA-N  SERMPMMEGHANCD     ZINC
# 76529  CPCJMIHIVOAJEG-JCMHNJIXSA-N  CPCJMIHIVOAJEG     ZINC
# 76530  JTLGIMMFHQVTQX-AWEZNQCLSA-N  JTLGIMMFHQVTQX     ZINC
# 76531  QKVQUQDHISLTBK-RBUKOAKNSA-N  QKVQUQDHISLTBK     ZINC
#
#                                                     ECFP  \
# 0      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 1      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 2      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 3      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 4      <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# ...                                                  ...
# 76527  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76528  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76529  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76530  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
# 76531  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...
#
#                                                   Bitset       RFT
# 0      (80, 142, 195, 226, 294, 314, 334, 339, 370, 5...  1.717874
# 1      (133, 137, 165, 216, 252, 314, 350, 382, 398, ...  0.820610
# 2      (45, 60, 133, 145, 222, 227, 231, 249, 282, 28...  1.794547
# 3      (35, 80, 176, 222, 294, 314, 408, 514, 650, 65...  1.975365
# 4      (1, 8, 80, 102, 197, 265, 310, 322, 367, 389, ...  0.439023
# ...                                                  ...       ...
# 76527  (24, 80, 165, 216, 231, 319, 350, 365, 366, 38... -1.881786
# 76528  (80, 93, 197, 221, 319, 322, 350, 374, 446, 52... -1.244183
# 76529  (74, 80, 95, 233, 235, 273, 281, 310, 314, 475... -1.441439
# 76530  (114, 119, 145, 270, 378, 392, 448, 449, 524, ... -0.433078
# 76531  (1, 14, 80, 117, 241, 291, 294, 350, 383, 446,... -1.100593
#
# [76532 rows x 9 columns]

# %%
fpr, tpr, thresholds = metrics.roc_curve(joint_samples['Name'], joint_samples['RFT'], pos_label = 'COCONUT')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/tmp/pbs.43231.lich-compute.vscht.cz/ipykernel_10574/1256656500.py in <module>
# ----> 1 fpr, tpr, thresholds = metrics.roc_curve(joint_samples['Name'], joint_samples['RFT'], pos_label = 'COCONUT')
#       2 roc_auc = metrics.auc(fpr, tpr)
#
# NameError: name 'metrics' is not defined

# %%
from matplotlib.pyplot import figure
plt.figure()
figure(figsize=(11.7, 8.27))
plt.plot(fpr,tpr,color="darkorange",label="ROC curve (area = %0.2f)" % roc_auc)
plt.plot([0, 1], [0, 1], color="navy", linestyle="--")
plt.xlim([-0.01, 1.01])
plt.ylim([0.0, 1.01])
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title('Receiver Operating Characteristic 0')
plt.legend(loc="lower right")
plt.savefig(f"../images//joint_samples_ROC0.svg", format="svg")
plt.show()
