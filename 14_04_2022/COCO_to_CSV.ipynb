# %% [markdown]
# ### COCO to CSV
# Creating new csv containg COCONUT data. 'MW': db_mw, 'logP':db_logP, 'Smiles': db_smiles, 'Inchi': db_inchikey, 'coconut_id': db_COCONUT_id

# %%
from rdkit.Chem import AllChem as Chem
from rdkit.Chem import Descriptors
from rdkit.Chem.Draw import IPythonConsole
import pandas as pd
from rdkit.Chem import rdMolDescriptors as rdescriptors
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import sys    
import pubchempy as pcp
import warnings
warnings.filterwarnings('ignore')
from rdkit import RDLogger 
RDLogger.DisableLog('rdApp.*')

# %%
#Loading coconut database from sdf format
coco = Chem.SDMolSupplier('COCONUT_DB.sdf')
coco_d = [m for m in coco if m]

# %%
#Number of natural products
len(coco_d)
# Out:
# 405960

# %%
# List of molecular octanol-water partition coefficient
db_logP = []
for substance in coco_d:
		db_logP.append(Descriptors.MolLogP(substance))

# %%
# List of molecular weights of natural products
db_mw = []
for substance in coco_d:
		db_mw.append(rdescriptors.CalcExactMolWt(substance))

# %%
#List of smiles
db_smiles = []
for substance in coco_d:
		db_smiles.append(Chem.MolToSmiles(substance))

# %%
#List of Inchikey
db_inchikey = []
for substance in coco_d:
		db_inchikey.append(Chem.MolToInchiKey(substance))

# %%
#List of Inchikey split
db_inchikey_s = []
for substance in coco_d:
		db_inchikey_s.append(Chem.MolToInchiKey(substance).split('-')[0])

# %%
#List of COCONUT_ID
db_COCONUT_id = []
for substance in coco_d:
		db_COCONUT_id.append(substance.GetProp('coconut_id'))

# %%
print(len(db_inchikey_s))
# Out:
# 405960

# %%
#Creating dataframe of logP, MW and smiles value of COCONUT products
df_COCO = pd.DataFrame(data={'Coconut_id': db_COCONUT_id, 'Smiles': db_smiles, 'MW': db_mw, 'logP':db_logP, 'Inchi': db_inchikey, 'Inchi_s': db_inchikey_s})

df_COCO['Name'] = "COCO"
df_COCO
# Out:
#         Coconut_id                                             Smiles  \
# 0       CNP0000002  CC=C(N=CS)C(=O)OC1C(COC(C)=O)OC(C2(O)CC(=O)C(N...
# 1       CNP0000003  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(OC)c5c4C...
# 2       CNP0000004  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(OC)c5c4C...
# 3       CNP0000005  CC1(C)CC2C(OC(=O)c3ccccc3)C(OC(=O)c3ccccc3)CC(...
# 4       CNP0000006  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(O)c5c4C(...
# ...            ...                                                ...
# 405955  CNP0436851                        COc1cccc2ccc(C(C)=O)c(O)c12
# 405956  CNP0436852  COc1cc(OC)c2c(c1)C(OC)(c1ccc3c(c1O)C(=O)c1c(O)...
# 405957  CNP0436853  CC1(C)C=Cc2cc(C3COc4c5c(cc(O)c4C3=O)OC(C)(C)C=...
# 405958  CNP0436854  CCCCCCCC1CC(=O)NC(CO)C(=O)NC(CO)C(=O)N2CCCC2C(...
# 405959  CNP0436855  CCCCCCCC1CC(=O)NC(C(C)C)C(=O)NC(C(O)C(C)C)C(=O...
#
#                  MW     logP                        Inchi         Inchi_s  \
# 0        660.183639 -2.08210  FJEMIESGEMWDOB-UHFFFAOYSA-N  FJEMIESGEMWDOB
# 1        598.183897  3.63422  KLWKJVYCDFWQMK-UHFFFAOYSA-N  KLWKJVYCDFWQMK
# 2        554.157682  3.32262  PTEKHLCNKCAXPH-UHFFFAOYSA-N  PTEKHLCNKCAXPH
# 3        534.298139  6.87940  ZVAVQCZAGOKAMX-UHFFFAOYSA-N  ZVAVQCZAGOKAMX
# 4        540.142032  3.01962  UYIPOCQHTAYRMA-UHFFFAOYSA-N  UYIPOCQHTAYRMA
# ...             ...      ...                          ...             ...
# 405955   216.078644  2.75660  XNWOWNYWQOTWIX-UHFFFAOYSA-N  XNWOWNYWQOTWIX
# 405956   570.188983  4.77902  XWGVAZYMLDVIDS-UHFFFAOYSA-N  XWGVAZYMLDVIDS
# 405957   420.157288  4.82510  XZXMEYSQXQNHCX-UHFFFAOYSA-N  XZXMEYSQXQNHCX
# 405958  1183.685261 -1.20930  YNLIJTVZSFUHKP-UHFFFAOYSA-N  YNLIJTVZSFUHKP
# 405959  1456.817732 -3.86630  ZQEJMIHHZHRPMS-UHFFFAOYSA-N  ZQEJMIHHZHRPMS
#
#         Name
# 0       COCO
# 1       COCO
# 2       COCO
# 3       COCO
# 4       COCO
# ...      ...
# 405955  COCO
# 405956  COCO
# 405957  COCO
# 405958  COCO
# 405959  COCO
#
# [405960 rows x 7 columns]

# %%
#Saving COCO pd dataframe to CSV
df_COCO.to_csv('ZINC_csv1/COCOALL.csv', sep=' ', index = False)

# %%
#Loading COCO database from csv 
suppl_csv = pd.read_csv('ZINC_csv1/COCOALL.csv', delimiter = ' ')
suppl_csv
# Out:
#         Coconut_id                                             Smiles  \
# 0       CNP0000002  CC=C(N=CS)C(=O)OC1C(COC(C)=O)OC(C2(O)CC(=O)C(N...
# 1       CNP0000003  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(OC)c5c4C...
# 2       CNP0000004  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(OC)c5c4C...
# 3       CNP0000005  CC1(C)CC2C(OC(=O)c3ccccc3)C(OC(=O)c3ccccc3)CC(...
# 4       CNP0000006  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(O)c5c4C(...
# ...            ...                                                ...
# 405955  CNP0436851                        COc1cccc2ccc(C(C)=O)c(O)c12
# 405956  CNP0436852  COc1cc(OC)c2c(c1)C(OC)(c1ccc3c(c1O)C(=O)c1c(O)...
# 405957  CNP0436853  CC1(C)C=Cc2cc(C3COc4c5c(cc(O)c4C3=O)OC(C)(C)C=...
# 405958  CNP0436854  CCCCCCCC1CC(=O)NC(CO)C(=O)NC(CO)C(=O)N2CCCC2C(...
# 405959  CNP0436855  CCCCCCCC1CC(=O)NC(C(C)C)C(=O)NC(C(O)C(C)C)C(=O...
#
#                  MW     logP                        Inchi         Inchi_s  \
# 0        660.183639 -2.08210  FJEMIESGEMWDOB-UHFFFAOYSA-N  FJEMIESGEMWDOB
# 1        598.183897  3.63422  KLWKJVYCDFWQMK-UHFFFAOYSA-N  KLWKJVYCDFWQMK
# 2        554.157682  3.32262  PTEKHLCNKCAXPH-UHFFFAOYSA-N  PTEKHLCNKCAXPH
# 3        534.298139  6.87940  ZVAVQCZAGOKAMX-UHFFFAOYSA-N  ZVAVQCZAGOKAMX
# 4        540.142032  3.01962  UYIPOCQHTAYRMA-UHFFFAOYSA-N  UYIPOCQHTAYRMA
# ...             ...      ...                          ...             ...
# 405955   216.078644  2.75660  XNWOWNYWQOTWIX-UHFFFAOYSA-N  XNWOWNYWQOTWIX
# 405956   570.188983  4.77902  XWGVAZYMLDVIDS-UHFFFAOYSA-N  XWGVAZYMLDVIDS
# 405957   420.157288  4.82510  XZXMEYSQXQNHCX-UHFFFAOYSA-N  XZXMEYSQXQNHCX
# 405958  1183.685261 -1.20930  YNLIJTVZSFUHKP-UHFFFAOYSA-N  YNLIJTVZSFUHKP
# 405959  1456.817732 -3.86630  ZQEJMIHHZHRPMS-UHFFFAOYSA-N  ZQEJMIHHZHRPMS
#
#         Name
# 0       COCO
# 1       COCO
# 2       COCO
# 3       COCO
# 4       COCO
# ...      ...
# 405955  COCO
# 405956  COCO
# 405957  COCO
# 405958  COCO
# 405959  COCO
#
# [405960 rows x 7 columns]

# %%
#Saving COCO pd dataframe to CSV
df_COCO.to_csv('ZINC_csv1/COCOFINAL.csv', sep=' ', index = False)

# %%
#Check duplicates in COCO dataframe
ids = df_COCO['Inchi_s']
df_COCO[ids.isin(ids[ids.duplicated()])].sort_values('Inchi_s')
# Out:
#         Coconut_id                                             Smiles  \
# 342105  CNP0369807          CCc1cc(=O)oc2cc(OCC(=O)NCCCCCC(=O)O)ccc12
# 305022  CNP0331440       CCc1cc(=O)oc2cc(OCC(=O)NCCCCCC(=O)[O-])ccc12
# 80871   CNP0098629  COC1=C(C)C(=O)OC1=C1OC2=CCC3CCC(O)(CC4CCCC45CC...
# 155052  CNP0175948  COC1=C(C)C(=O)OC1=C1OC2=CCC3CCC(O)(CC4CCCC45CC...
# 295845  CNP0321925  CC(CO)=C1CCc2ccc(cc2)C2C=CC(c3cccc(Cc4ccccc4)c...
# ...            ...                                                ...
# 40805   CNP0052001  CC12CC=CC3(C4=CCC5C6(C)CCC(OC7OC(C(=O)[O-])C(O...
# 66277   CNP0083286                              O=C1OC(CO)C([O-])=C1O
# 229469  CNP0253154                                 O=C1OC(CO)C(O)=C1O
# 380188  CNP0409188    CCCC(NC(=O)C(C)Oc1ccc2c(C)cc(=O)oc2c1)C(=O)[O-]
# 333741  CNP0361169       CCCC(NC(=O)C(C)Oc1ccc2c(C)cc(=O)oc2c1)C(=O)O
#
#                 MW     logP                        Inchi         Inchi_s  Name
# 342105  361.152537  2.49540  AAAPEXAGBQZUNL-UHFFFAOYSA-N  AAAPEXAGBQZUNL  COCO
# 305022  360.145261  1.16070  AAAPEXAGBQZUNL-UHFFFAOYSA-M  AAAPEXAGBQZUNL  COCO
# 80871   524.337050  4.69540  AABJOSWGDPWIAI-UHFFFAOYSA-O  AABJOSWGDPWIAI  COCO
# 155052  523.329774  6.11250  AABJOSWGDPWIAI-UHFFFAOYSA-N  AABJOSWGDPWIAI  COCO
# 295845  909.420839  9.12370  AABKOYXSWYMOPH-UHFFFAOYSA-O  AABKOYXSWYMOPH  COCO
# ...            ...      ...                          ...             ...   ...
# 40805   670.372795  1.76170  ZZZCIBDNNQUEGX-UHFFFAOYSA-L  ZZZCIBDNNQUEGX  COCO
# 66277   145.014247 -1.96600  ZZZCUOFIHGPKAK-UHFFFAOYSA-M  ZZZCUOFIHGPKAK  COCO
# 229469  146.021523 -0.76830  ZZZCUOFIHGPKAK-UHFFFAOYSA-N  ZZZCUOFIHGPKAK  COCO
# 380188  346.129611  0.90352  ZZZOCTGZIOGBLT-UHFFFAOYSA-M  ZZZOCTGZIOGBLT  COCO
# 333741  347.136887  2.23822  ZZZOCTGZIOGBLT-UHFFFAOYSA-N  ZZZOCTGZIOGBLT  COCO
#
# [39044 rows x 7 columns]

# %%
#Drop duplicates
df_COCO = df_COCO.drop_duplicates(subset=['Inchi_s'])
df_COCO
#Check duplicates
ids = df_COCO['Inchi_s']
df_COCO[ids.isin(ids[ids.duplicated()])].sort_values('Inchi_s')
# Out:
# Empty DataFrame
# Columns: [Coconut_id, Smiles, MW, logP, Inchi, Inchi_s, Name]
# Index: []

# %%
df_COCO
# Out:
#         Coconut_id                                             Smiles  \
# 0       CNP0000002  CC=C(N=CS)C(=O)OC1C(COC(C)=O)OC(C2(O)CC(=O)C(N...
# 1       CNP0000003  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(OC)c5c4C...
# 2       CNP0000004  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(OC)c5c4C...
# 3       CNP0000005  CC1(C)CC2C(OC(=O)c3ccccc3)C(OC(=O)c3ccccc3)CC(...
# 4       CNP0000006  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(O)c5c4C(...
# ...            ...                                                ...
# 405955  CNP0436851                        COc1cccc2ccc(C(C)=O)c(O)c12
# 405956  CNP0436852  COc1cc(OC)c2c(c1)C(OC)(c1ccc3c(c1O)C(=O)c1c(O)...
# 405957  CNP0436853  CC1(C)C=Cc2cc(C3COc4c5c(cc(O)c4C3=O)OC(C)(C)C=...
# 405958  CNP0436854  CCCCCCCC1CC(=O)NC(CO)C(=O)NC(CO)C(=O)N2CCCC2C(...
# 405959  CNP0436855  CCCCCCCC1CC(=O)NC(C(C)C)C(=O)NC(C(O)C(C)C)C(=O...
#
#                  MW     logP                        Inchi         Inchi_s  \
# 0        660.183639 -2.08210  FJEMIESGEMWDOB-UHFFFAOYSA-N  FJEMIESGEMWDOB
# 1        598.183897  3.63422  KLWKJVYCDFWQMK-UHFFFAOYSA-N  KLWKJVYCDFWQMK
# 2        554.157682  3.32262  PTEKHLCNKCAXPH-UHFFFAOYSA-N  PTEKHLCNKCAXPH
# 3        534.298139  6.87940  ZVAVQCZAGOKAMX-UHFFFAOYSA-N  ZVAVQCZAGOKAMX
# 4        540.142032  3.01962  UYIPOCQHTAYRMA-UHFFFAOYSA-N  UYIPOCQHTAYRMA
# ...             ...      ...                          ...             ...
# 405955   216.078644  2.75660  XNWOWNYWQOTWIX-UHFFFAOYSA-N  XNWOWNYWQOTWIX
# 405956   570.188983  4.77902  XWGVAZYMLDVIDS-UHFFFAOYSA-N  XWGVAZYMLDVIDS
# 405957   420.157288  4.82510  XZXMEYSQXQNHCX-UHFFFAOYSA-N  XZXMEYSQXQNHCX
# 405958  1183.685261 -1.20930  YNLIJTVZSFUHKP-UHFFFAOYSA-N  YNLIJTVZSFUHKP
# 405959  1456.817732 -3.86630  ZQEJMIHHZHRPMS-UHFFFAOYSA-N  ZQEJMIHHZHRPMS
#
#         Name
# 0       COCO
# 1       COCO
# 2       COCO
# 3       COCO
# 4       COCO
# ...      ...
# 405955  COCO
# 405956  COCO
# 405957  COCO
# 405958  COCO
# 405959  COCO
#
# [386297 rows x 7 columns]

# %%
df_COCO.to_csv('ZINC_csv1/COCOFINAL.csv', sep=' ', index = False)

# %%
#Loading zinc database from csv 
suppl_csv = pd.read_csv('ZINC_csv1/COCOFINAL.csv', delimiter = ' ')
suppl_csv
# Out:
#         Coconut_id                                             Smiles  \
# 0       CNP0000002  CC=C(N=CS)C(=O)OC1C(COC(C)=O)OC(C2(O)CC(=O)C(N...
# 1       CNP0000003  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(OC)c5c4C...
# 2       CNP0000004  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(OC)c5c4C...
# 3       CNP0000005  CC1(C)CC2C(OC(=O)c3ccccc3)C(OC(=O)c3ccccc3)CC(...
# 4       CNP0000006  COc1cc(C)cc2c1C(=O)OC1C(O)C=CC3c4c(cc(O)c5c4C(...
# ...            ...                                                ...
# 386292  CNP0436851                        COc1cccc2ccc(C(C)=O)c(O)c12
# 386293  CNP0436852  COc1cc(OC)c2c(c1)C(OC)(c1ccc3c(c1O)C(=O)c1c(O)...
# 386294  CNP0436853  CC1(C)C=Cc2cc(C3COc4c5c(cc(O)c4C3=O)OC(C)(C)C=...
# 386295  CNP0436854  CCCCCCCC1CC(=O)NC(CO)C(=O)NC(CO)C(=O)N2CCCC2C(...
# 386296  CNP0436855  CCCCCCCC1CC(=O)NC(C(C)C)C(=O)NC(C(O)C(C)C)C(=O...
#
#                  MW     logP                        Inchi         Inchi_s  \
# 0        660.183639 -2.08210  FJEMIESGEMWDOB-UHFFFAOYSA-N  FJEMIESGEMWDOB
# 1        598.183897  3.63422  KLWKJVYCDFWQMK-UHFFFAOYSA-N  KLWKJVYCDFWQMK
# 2        554.157682  3.32262  PTEKHLCNKCAXPH-UHFFFAOYSA-N  PTEKHLCNKCAXPH
# 3        534.298139  6.87940  ZVAVQCZAGOKAMX-UHFFFAOYSA-N  ZVAVQCZAGOKAMX
# 4        540.142032  3.01962  UYIPOCQHTAYRMA-UHFFFAOYSA-N  UYIPOCQHTAYRMA
# ...             ...      ...                          ...             ...
# 386292   216.078644  2.75660  XNWOWNYWQOTWIX-UHFFFAOYSA-N  XNWOWNYWQOTWIX
# 386293   570.188983  4.77902  XWGVAZYMLDVIDS-UHFFFAOYSA-N  XWGVAZYMLDVIDS
# 386294   420.157288  4.82510  XZXMEYSQXQNHCX-UHFFFAOYSA-N  XZXMEYSQXQNHCX
# 386295  1183.685261 -1.20930  YNLIJTVZSFUHKP-UHFFFAOYSA-N  YNLIJTVZSFUHKP
# 386296  1456.817732 -3.86630  ZQEJMIHHZHRPMS-UHFFFAOYSA-N  ZQEJMIHHZHRPMS
#
#         Name
# 0       COCO
# 1       COCO
# 2       COCO
# 3       COCO
# 4       COCO
# ...      ...
# 386292  COCO
# 386293  COCO
# 386294  COCO
# 386295  COCO
# 386296  COCO
#
# [386297 rows x 7 columns]
