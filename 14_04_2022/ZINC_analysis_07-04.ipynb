# %% [markdown]
# ## ZINC_analysis_07-04

# %% [markdown]
# Removing duplicates across sampled ZINC substances, exactly 10 substances with identical first INCHIKEY part. Creating new csv with ZINC substances, containing zinc_id, Smiles, MW, logP, INCHIKEY (Inchi) and Inchikey first part (Inchi_s).

# %%
#Libraries
from rdkit.Chem import AllChem as Chem
from rdkit.Chem import Descriptors
from rdkit.Chem.Draw import IPythonConsole
import pandas as pd
from rdkit.Chem import rdMolDescriptors as rdescriptors
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
from rdkit import RDLogger 
RDLogger.DisableLog('rdApp.*')

# %%
#Loading zinc database from csv 
suppl_csv = pd.read_csv('ZINC_csv1/ZINCALL.csv', delimiter = ' ')
suppl_csv
# Out:
#                                                    Smiles    zinc_id
# 0                                 N=C(N)NCC[C@H](N)C(=O)O    1589384
# 1                                     CN(C)CC(=O)NCC(=O)O   83822513
# 2                                   O=C(O)CN1CCCNS1(=O)=O  214763687
# 3              O=C(O)[C@@H]1C[C@H]2O[C@H]1[C@H](O)[C@H]2O  306392345
# 4                           N[C@@H]1N=C2N=C(O)N=C2C(=O)N1   85343607
# ...                                                   ...        ...
# 379017  Cc1ccc(C(=O)N(c2ccc(N(C(=O)c3ccc(C)cc3)S(=O)(=...   97986502
# 379018  CCc1c(-c2ccc(OC)c(OC)c2)nn(-c2nc(-c3ccc(C)cc3)...   97948800
# 379019  Cc1cc(N2CCN(CCOc3cccc4ccccc34)CC2)n2nc(C)c(-c3...   54274624
# 379020        CCOc1cc(CNc2cc(Cl)ccc2C)cc(I)c1OCc1ccccc1Cl    2093448
# 379021  CCCOc1cccc([C@@H]2C(S(=O)(=O)c3ccccc3)=C(O)C(=...   24193211
#
# [379022 rows x 2 columns]

# %%
#Number of zinc products
len(suppl_csv)
# Out:
# 379022

# %%
# List of molecular weights of zinc products
ligandm_database = []
for ligand in suppl_csv["Smiles"]:
		ligandm_database.append(Chem.MolFromSmiles(ligand))

# %%
#List of MW from csv
db_MW_z = []
for substance in ligandm_database:
		db_MW_z.append(rdescriptors.CalcExactMolWt(substance))
print(len(db_MW_z))

#List of logP from csv
db_logP_z = []
for substance in ligandm_database:
		db_logP_z.append(Descriptors.MolLogP(substance))
print(len(db_logP_z))
# Out:
# 379022
# 379022

# %%
#List of INCHI from csv
db_Inchi = []
for substance in ligandm_database:
		db_Inchi.append(Chem.MolToInchiKey(substance))
print(len(db_Inchi))
# Out:
# 379022

# %%
#List of INCHI_s from csv
db_Inchi_z = []
for substance in ligandm_database:
		db_Inchi_z.append(Chem.MolToInchiKey(substance).split('-')[0])
print(len(db_Inchi_z))
# Out:
# 379022

# %%
#Creating dataframe smiles and of ZINC products
df_ZINC = pd.DataFrame(data={'Zinc_id': suppl_csv['zinc_id'], 'Smiles': suppl_csv['Smiles'], 'MW': db_MW_z,  'logP': db_logP_z, 'Inchi': db_Inchi, 'Inchi_s': db_Inchi_z})
                    
df_ZINC['Name'] = "ZINC"
df_ZINC
# Out:
#           Zinc_id                                             Smiles  \
# 0         1589384                            N=C(N)NCC[C@H](N)C(=O)O
# 1        83822513                                CN(C)CC(=O)NCC(=O)O
# 2       214763687                              O=C(O)CN1CCCNS1(=O)=O
# 3       306392345         O=C(O)[C@@H]1C[C@H]2O[C@H]1[C@H](O)[C@H]2O
# 4        85343607                      N[C@@H]1N=C2N=C(O)N=C2C(=O)N1
# ...           ...                                                ...
# 379017   97986502  Cc1ccc(C(=O)N(c2ccc(N(C(=O)c3ccc(C)cc3)S(=O)(=...
# 379018   97948800  CCc1c(-c2ccc(OC)c(OC)c2)nn(-c2nc(-c3ccc(C)cc3)...
# 379019   54274624  Cc1cc(N2CCN(CCOc3cccc4ccccc34)CC2)n2nc(C)c(-c3...
# 379020    2093448        CCOc1cc(CNc2cc(Cl)ccc2C)cc(I)c1OCc1ccccc1Cl
# 379021   24193211  CCCOc1cccc([C@@H]2C(S(=O)(=O)c3ccccc3)=C(O)C(=...
#
#                 MW     logP                        Inchi         Inchi_s  Name
# 0       160.096026 -1.72853  IFPQOXNWLSRZKX-VKHMYHEASA-N  IFPQOXNWLSRZKX  ZINC
# 1       160.084792 -1.25120  HQFNONZTUQSPJS-UHFFFAOYSA-N  HQFNONZTUQSPJS  ZINC
# 2       194.036128 -1.38890  KCIDTUHJDPZBTQ-UHFFFAOYSA-N  KCIDTUHJDPZBTQ  ZINC
# 3       174.052823 -1.41990  ZZTJOHOETCDWML-VFUOTHLCSA-N  ZZTJOHOETCDWML  ZINC
# 4       167.044324 -1.87440  OSXQHYVRCFCLQV-SCSAIBSYSA-N  OSXQHYVRCFCLQV  ZINC
# ...            ...      ...                          ...             ...   ...
# 379017  636.051720  6.49784  KYPDAVIHIYTGQW-UHFFFAOYSA-N  KYPDAVIHIYTGQW  ZINC
# 379018  604.229740  7.58732  AWQWFNRTEBAZJO-UHFFFAOYSA-N  AWQWFNRTEBAZJO  ZINC
# 379019  511.213888  6.02074  HAHVCBFPDRUVIL-UHFFFAOYSA-N  HAHVCBFPDRUVIL  ZINC
# 379020  541.007232  7.49622  IYFPBZIIJDRXMB-UHFFFAOYSA-N  IYFPBZIIJDRXMB  ZINC
# 379021  517.051749  6.11360  LDSGAMYJONZMDX-JOCHJYFZSA-N  LDSGAMYJONZMDX  ZINC
#
# [379022 rows x 7 columns]

# %%
#Check duplicates in ZINC dataframe
ids = df_ZINC['Inchi_s']
df_ZINC[ids.isin(ids[ids.duplicated()])].sort_values('Inchi_s')
# Out:
#           Zinc_id                                             Smiles  \
# 239279  239275070  CC[C@H](C)[C@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@H]...
# 280218  150631027  CC[C@H](C)[C@H](NC(=O)[C@H](CC(C)C)NC(=O)[C@H]...
# 239232  239296785  CC(=O)O[C@H](C(=O)NC[C@H]1CCCO1)[C@@H](OC(C)=O...
# 280077   97940073  CC(=O)O[C@H](C(=O)NC[C@@H]1CCCO1)[C@@H](OC(C)=...
# 238519  239309554  C[C@H](O)[C@H](NC(=O)OC(C)(C)C)C(=O)N[C@H](CC(...
# 278086    4091778  C[C@@H](O)[C@@H](NC(=O)OC(C)(C)C)C(=O)N[C@@H](...
# 244796  239310113  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCC(=O)N1C(=O)OCc...
# 288056    4177603  CC[C@H](C)[C@H](NC(=O)[C@@H]1CCC(=O)N1C(=O)OCc...
# 239130  238901046  CC(C)[C@H](C(=O)Nc1nc(O)c2ncn([C@@H]3O[C@H](CO...
# 278774   11666771  CC(C)[C@@H](C(=O)Nc1nc2c(ncn2[C@@H]2O[C@@H](CO...
# 282931    8396105  CCOC(=O)COc1c(Cl)cc(C([C@H]2C(=O)NC(=S)N(C)C2=...
# 240367  239135356  CCOC(=O)COc1c(Cl)cc([C@H]([C@H]2C(=O)NC(=S)N(C...
# 245259  239338799  CCOC(=O)[C@@H]1CCCN([C@H]2CC(=O)N(c3ccc(N4C(=O...
# 288514   17356814  CCOC(=O)[C@@H]1CCCN([C@@H]2CC(=O)N(c3ccc(N4C(=...
# 239479  239203359  CC(C)C[C@H](NC(=O)[C@H](Cc1ccccc1)NC(=O)CNC(=O...
# 279905  150662600  CC(C)C[C@H](NC(=O)[C@@H](Cc1ccccc1)NC(=O)CNC(=...
# 240447  239235520  CC(C)(C)OC(=O)N[C@H](CC(N)=O)C(=O)N[C@@H](CO)C...
# 283836    4091791  CC(C)(C)OC(=O)N[C@H](CC(N)=O)C(=O)N[C@@H](CO)C...
# 278096  253612605  CC(=O)OC[C@@H]1O[C@@](COC(C)=O)(O[C@H]2O[C@@H]...
# 238362  238809628  CC(=O)OC[C@H]1O[C@@H](OC[C@H]2O[C@@H](O[C@]3(C...
#
#                 MW     logP                        Inchi         Inchi_s  Name
# 239279  660.348277 -0.70240  BDERCNWRQAOVNB-JBIWOSBCSA-N  BDERCNWRQAOVNB  ZINC
# 280218  660.348277 -0.70240  BDERCNWRQAOVNB-GYTVCLMCSA-N  BDERCNWRQAOVNB  ZINC
# 239232  544.226825 -0.69640  DHZGKAWIFVVCSS-ZCPXKWAGSA-N  DHZGKAWIFVVCSS  ZINC
# 280077  544.226825 -0.69640  DHZGKAWIFVVCSS-BPIQYHPVSA-N  DHZGKAWIFVVCSS  ZINC
# 238519  672.311892 -1.11040  HRTZNWOMIISGRQ-SQFLVMJDSA-N  HRTZNWOMIISGRQ  ZINC
# 278086  672.311892 -1.11040  HRTZNWOMIISGRQ-KIHRHZKDSA-N  HRTZNWOMIISGRQ  ZINC
# 244796  571.300599  1.46220  ICWOBLRWDHMGJE-CPAPFFTJSA-N  ICWOBLRWDHMGJE  ZINC
# 288056  571.300599  1.46220  ICWOBLRWDHMGJE-OQCQCTNUSA-N  ICWOBLRWDHMGJE  ZINC
# 239130  512.165562 -0.59730  KQNLYZWFWSWXOV-HZEGDUTGSA-N  KQNLYZWFWSWXOV  ZINC
# 278774  512.165562 -1.00960  KQNLYZWFWSWXOV-KZDMQCJOSA-N  KQNLYZWFWSWXOV  ZINC
# 282931  570.064583  0.35270  LCUZBEMNSMULLH-GOOCMWNKSA-N  LCUZBEMNSMULLH  ZINC
# 240367  570.064583  0.35270  LCUZBEMNSMULLH-QDMKHBRRSA-N  LCUZBEMNSMULLH  ZINC
# 245259  582.268964  1.50060  LGOAXZLLIJEMGB-DVJXIFHOSA-N  LGOAXZLLIJEMGB  ZINC
# 288514  582.268964  1.50060  LGOAXZLLIJEMGB-FAYOUJPWSA-N  LGOAXZLLIJEMGB  ZINC
# 239479  648.359510 -0.28163  SFEMUUMEPTYWHN-FSSWDIPSSA-N  SFEMUUMEPTYWHN  ZINC
# 279905  648.359510 -0.28163  SFEMUUMEPTYWHN-BHIFYINESA-N  SFEMUUMEPTYWHN  ZINC
# 240447  571.264213  0.02400  WCPSVQMNXJGSLD-VSKRKVRLSA-N  WCPSVQMNXJGSLD  ZINC
# 283836  571.264213  0.02400  WCPSVQMNXJGSLD-BDTNDASRSA-N  WCPSVQMNXJGSLD  ZINC
# 278096  966.285246 -1.29260  YFYHLVDRBNRNPU-JAFGELGUSA-N  YFYHLVDRBNRNPU  ZINC
# 238362  966.285246 -1.29260  YFYHLVDRBNRNPU-HXBGYFMASA-N  YFYHLVDRBNRNPU  ZINC

# %%
#Drop duplicates
df_ZINC = df_ZINC.drop_duplicates(subset=['Inchi_s'])
df_ZINC
#Check duplicates
ids = df_ZINC['Inchi_s']
df_ZINC[ids.isin(ids[ids.duplicated()])].sort_values('Inchi_s')
# Out:
# Empty DataFrame
# Columns: [Zinc_id, Smiles, MW, logP, Inchi, Inchi_s, Name]
# Index: []

# %%
print(len(df_ZINC))
# Out:
# 379012

# %%
df_ZINC
# Out:
#           Zinc_id                                             Smiles  \
# 0         1589384                            N=C(N)NCC[C@H](N)C(=O)O
# 1        83822513                                CN(C)CC(=O)NCC(=O)O
# 2       214763687                              O=C(O)CN1CCCNS1(=O)=O
# 3       306392345         O=C(O)[C@@H]1C[C@H]2O[C@H]1[C@H](O)[C@H]2O
# 4        85343607                      N[C@@H]1N=C2N=C(O)N=C2C(=O)N1
# ...           ...                                                ...
# 379017   97986502  Cc1ccc(C(=O)N(c2ccc(N(C(=O)c3ccc(C)cc3)S(=O)(=...
# 379018   97948800  CCc1c(-c2ccc(OC)c(OC)c2)nn(-c2nc(-c3ccc(C)cc3)...
# 379019   54274624  Cc1cc(N2CCN(CCOc3cccc4ccccc34)CC2)n2nc(C)c(-c3...
# 379020    2093448        CCOc1cc(CNc2cc(Cl)ccc2C)cc(I)c1OCc1ccccc1Cl
# 379021   24193211  CCCOc1cccc([C@@H]2C(S(=O)(=O)c3ccccc3)=C(O)C(=...
#
#                 MW     logP                        Inchi         Inchi_s  Name
# 0       160.096026 -1.72853  IFPQOXNWLSRZKX-VKHMYHEASA-N  IFPQOXNWLSRZKX  ZINC
# 1       160.084792 -1.25120  HQFNONZTUQSPJS-UHFFFAOYSA-N  HQFNONZTUQSPJS  ZINC
# 2       194.036128 -1.38890  KCIDTUHJDPZBTQ-UHFFFAOYSA-N  KCIDTUHJDPZBTQ  ZINC
# 3       174.052823 -1.41990  ZZTJOHOETCDWML-VFUOTHLCSA-N  ZZTJOHOETCDWML  ZINC
# 4       167.044324 -1.87440  OSXQHYVRCFCLQV-SCSAIBSYSA-N  OSXQHYVRCFCLQV  ZINC
# ...            ...      ...                          ...             ...   ...
# 379017  636.051720  6.49784  KYPDAVIHIYTGQW-UHFFFAOYSA-N  KYPDAVIHIYTGQW  ZINC
# 379018  604.229740  7.58732  AWQWFNRTEBAZJO-UHFFFAOYSA-N  AWQWFNRTEBAZJO  ZINC
# 379019  511.213888  6.02074  HAHVCBFPDRUVIL-UHFFFAOYSA-N  HAHVCBFPDRUVIL  ZINC
# 379020  541.007232  7.49622  IYFPBZIIJDRXMB-UHFFFAOYSA-N  IYFPBZIIJDRXMB  ZINC
# 379021  517.051749  6.11360  LDSGAMYJONZMDX-JOCHJYFZSA-N  LDSGAMYJONZMDX  ZINC
#
# [379012 rows x 7 columns]

# %%
df_ZINC.to_csv('ZINC_csv1/ZINCFINAL.csv', sep=' ', index = False)

# %%
#Loading zinc database from csv 
suppl_csv = pd.read_csv('ZINC_csv1/ZINCFINAL.csv', delimiter = ' ')
suppl_csv
# Out:
#           Zinc_id                                             Smiles  \
# 0         1589384                            N=C(N)NCC[C@H](N)C(=O)O
# 1        83822513                                CN(C)CC(=O)NCC(=O)O
# 2       214763687                              O=C(O)CN1CCCNS1(=O)=O
# 3       306392345         O=C(O)[C@@H]1C[C@H]2O[C@H]1[C@H](O)[C@H]2O
# 4        85343607                      N[C@@H]1N=C2N=C(O)N=C2C(=O)N1
# ...           ...                                                ...
# 379007   97986502  Cc1ccc(C(=O)N(c2ccc(N(C(=O)c3ccc(C)cc3)S(=O)(=...
# 379008   97948800  CCc1c(-c2ccc(OC)c(OC)c2)nn(-c2nc(-c3ccc(C)cc3)...
# 379009   54274624  Cc1cc(N2CCN(CCOc3cccc4ccccc34)CC2)n2nc(C)c(-c3...
# 379010    2093448        CCOc1cc(CNc2cc(Cl)ccc2C)cc(I)c1OCc1ccccc1Cl
# 379011   24193211  CCCOc1cccc([C@@H]2C(S(=O)(=O)c3ccccc3)=C(O)C(=...
#
#                 MW     logP                        Inchi         Inchi_s  Name
# 0       160.096026 -1.72853  IFPQOXNWLSRZKX-VKHMYHEASA-N  IFPQOXNWLSRZKX  ZINC
# 1       160.084792 -1.25120  HQFNONZTUQSPJS-UHFFFAOYSA-N  HQFNONZTUQSPJS  ZINC
# 2       194.036128 -1.38890  KCIDTUHJDPZBTQ-UHFFFAOYSA-N  KCIDTUHJDPZBTQ  ZINC
# 3       174.052823 -1.41990  ZZTJOHOETCDWML-VFUOTHLCSA-N  ZZTJOHOETCDWML  ZINC
# 4       167.044324 -1.87440  OSXQHYVRCFCLQV-SCSAIBSYSA-N  OSXQHYVRCFCLQV  ZINC
# ...            ...      ...                          ...             ...   ...
# 379007  636.051720  6.49784  KYPDAVIHIYTGQW-UHFFFAOYSA-N  KYPDAVIHIYTGQW  ZINC
# 379008  604.229740  7.58732  AWQWFNRTEBAZJO-UHFFFAOYSA-N  AWQWFNRTEBAZJO  ZINC
# 379009  511.213888  6.02074  HAHVCBFPDRUVIL-UHFFFAOYSA-N  HAHVCBFPDRUVIL  ZINC
# 379010  541.007232  7.49622  IYFPBZIIJDRXMB-UHFFFAOYSA-N  IYFPBZIIJDRXMB  ZINC
# 379011  517.051749  6.11360  LDSGAMYJONZMDX-JOCHJYFZSA-N  LDSGAMYJONZMDX  ZINC
#
# [379012 rows x 7 columns]
